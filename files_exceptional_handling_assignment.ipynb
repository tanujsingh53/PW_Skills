# %% [markdown]
# Q1. What is the difference between interpreted and compiled languages?
#
# A1. Interpreted languages run line-by-line, compiled languages run after compiling the full code.

# %% [markdown]
# Q2. What is exception handling in Python?
#
# A2. It handles runtime errors using try, except blocks.

# %% [markdown]
# Q3. What is the purpose of the finally block in exception handling?
#
# A3. To execute code after try/except, regardless of outcome.

# %% [markdown]
# Q4. What is logging in Python?
#
# A4. Logging records program execution events and errors.

# %% [markdown]
# Q5. Whats the significance of the _.
#
# A5. __del__ is a destructor method called when an object is deleted.

# %% [markdown]
# Q6. What is the difference between import and from ... import in Python?
#
# A6. import brings the full module; from ... import brings specific elements
#
#
# Q7. 7. How can you handle multiple exceptions in Python?
#
# A7. Use multiple except blocks or handle as a tuple in one except.
#
#
# Q8. What is the purpose of the with statement when hani
#
# A8. It ensures files are properly closed after use.
#
# Q9. What is the difference between multithreading and multiprocessing?
# A9. Multithreading shares memory; multiprocessing uses separate processes.
#
# Q10. 19 files in Python?
#
# A10. Helps debug and monitor the program flow and issues.
#
# Q11. 10. What are the advantages of using logging in a program?
#
# A11. Python uses reference counting and garbage collection.
#
# Q12. What is memory management in Python?
#
# A12. Wrap risky code in try, handle errors in except.
#
# Q13. What are the basic steps involved in exception handling in Python?
#
# A13. To avoid memory leaks and ensure efficient usage.
#
# Q14. Why is memory management important in Python?
#
# A14. It helps catch and respond to exceptions.
#
# Q15. What is the role of try and except in exception handling?
#
# A15. It frees memory by removing unused objects.
#
# Q16. How does Python's garbage collection system work?
#
# A16. Runs code if no exception occurs in try block.
#
# Q17. What is the purpose of the else block in exception handling?
#
# A17. DEBUG, INFO, WARNING, ERROR, CRITICAL.
#
# Q18. What are the common logging levels in Python?
#
# A18. os.fork() is UNIX-only; multiprocessing works cross-platform.
#
# Q19. What is the difference between os fork() and multiprocessing in Python?
#
# A19. To save changes and free system resources.
#
# Q20. What is the importance of closing a file in Python?
#
# A20. read() reads whole file; readline() reads line-by-line.
#
# Q21. What is the difference between file.read() and file.readline() in Python?
#
# A21. To track events that happen during execution.
#
# Q22. What is the logging module in Python used for?
#
# A22. os handles file, directory, and path operations.
#
# Q23. What is the os module in Python used for in file handling?
#
# A23. Fragmentation, memory leaks, and performance drops.
#
# Q24. What are the challenges associated with memory management in Python?
#
# A24. Use the raise keyword with an Exception type.
#
# Q25. How do you raise an exception manually in Python?
#
# A25. For efficient CPU usage and handling concurrent tasks.
#
# Q26. Why is it important to use multithreading in certain applications?
#
# A26. In Python, multithreading is important because:
#
# ✅ It allows concurrent execution of tasks (especially I/O-bound like file or network operations).
#
# 🖥️ Keeps GUIs responsive during long background tasks.
#
# 🔁 Improves efficiency by handling multiple operations at once.
#
# 📡 Useful for web scraping, servers, and API calls where waiting time is high.

# %%
#Practical Questions

#Q1: How can you open a file for writing in Python and write a string to it.

with open("example.txt", "w") as file:
    file.write("Hello, this is a sample text.")

# %%
#Q2: Write a Python program to read the contents of a file and print each line.

with open("example.txt", "r") as file:
    # Loop through each line in the file
    for line in file:
        print(line.strip())
# Out:
# Hello, this is a sample text.

# %%
#Q3:  How would you handle a case where the file doesn't exist while trying to open it for readings.

filename = "example.txt"

try:
    with open(filename, "r") as file:
        for line in file:
            print(line.strip())
except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found.")
# Out:
# Hello, this is a sample text.

# %%
#Q4:  Write a Python script that reads from one file and writes its content to another file.

with open("source.txt", "r") as source_file:
    content = source_file.read()

with open("destination.txt", "w") as destination_file:
    destination_file.write(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4da74a8f4a47> in <cell line: 0>()
#       1 #Q4:  Write a Python script that reads from one file and writes its content to another file.
#       2
# ----> 3 with open("source.txt", "r") as source_file:
#       4     content = source_file.read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source.txt'

# %%
#Q5: How would you catch and handle division by zero error in Python.

try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %%
#Q6: Write a Python program that logs an error message to a log file when a division by zero exception occurs

import logging

# Set up logging configuration
logging.basicConfig(filename='error_log.txt', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

try:
    num = 10
    denom = 0
    result = num / denom
except ZeroDivisionError as e:
    logging.error("Division by zero occurred: %s", e)
    print("An error occurred. Check error_log.txt for details.")
# Out:
# ERROR:root:Division by zero occurred: division by zero
# An error occurred. Check error_log.txt for details.

# %%
#Q7: F How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

import logging

# Configure logging
logging.basicConfig(filename='app.log', level=logging.DEBUG,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Log messages at different levels
logging.debug("This is a DEBUG message.")
logging.info("This is an INFO message.")
logging.warning("This is a WARNING message.")
logging.error("This is an ERROR message.")
logging.critical("This is a CRITICAL message.")
# Out:
# WARNING:root:This is a WARNING message.
# ERROR:root:This is an ERROR message.
# CRITICAL:root:This is a CRITICAL message.

# %%
#Q8: Write a program to handle a file opening error using exception handling.

try:
    with open("non_existing_file.txt", "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Error: The file does not exist.

# %%
#Q9: How can you read a file line by line and store its content in a list in Python.

with open("example.txt", "r") as file:
    lines = file.readlines()


with open("example.txt", "r") as file:
    lines = file.readlines()

# %%
#Q10:  How can you append data to an existing file in Python?

with open("example.txt", "a") as file:
    file.write("This is new content being appended.\n")

# %%
#Q11: Write a Python program that uses a try-except block to handle an error when attempting to access adictionary key that doesn't exist.

# Sample dictionary
student = {"name": "John", "age": 20}

try:
    print("Student grade is:", student["grade"])
except KeyError:
    print("Error: 'grade' key does not exist in the dictionary.")
# Out:
# Error: 'grade' key does not exist in the dictionary.

# %%
#Q12: Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

try:
    num = int(input("Enter a number: "))
    result = 10 / num
    items = [1, 2, 3]
    print(items[5])
except ValueError:
    print("Error: Please enter a valid number.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except IndexError:
    print("Error: List index out of range.")
# Out:
# Enter a number: 2
# Error: List index out of range.

# %%
#Q13: How would you check if a file exists before attempting to read it in Python?

#Method 1: Using os.path.exists()
import os

if os.path.exists("example.txt"):
    with open("example.txt", "r") as file:
        content = file.read()
        print(content)
else:
    print("File does not exist.")


#Method 2: Using pathlib.Path
from pathlib import Path

file_path = Path("example.txt")
if file_path.exists():
    with file_path.open("r") as file:
        print(file.read())
else:
    print("File does not exist.")
# Out:
# Hello, this is a sample text.This is new content being appended.
#
# Hello, this is a sample text.This is new content being appended.

# %%
#Q14: Write a program that uses the logging module to log both informational and error messages.

import logging

# Configure logging
logging.basicConfig(filename='app_log.txt', level=logging.DEBUG,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Log an informational message
logging.info("Program started successfully.")

try:
    x = 10
    y = 0
    result = x / y
except ZeroDivisionError as e:
    logging.error("An error occurred: Division by zero.")
else:
    logging.info(f"Calculation successful: {result}")
# Out:
# ERROR:root:An error occurred: Division by zero.

# %%
#Q15: def read_and_print_file(filename):

def read_and_print_file(filename):
    try:
        with open(filename, "r") as file:
            content = file.read()
            if content.strip() == "":
                print("The file is empty.")
            else:
                print("File content:\n", content)
    except FileNotFoundError:
        print("Error: File not found.")

# Example usage
read_and_print_file("example.txt")
# Out:
# File content:
#  Hello, this is a sample text.This is new content being appended.

# %%
#Q16:  Demonstrate how to use memory profiling to check the memory usage of a small program.

#To profile memory usage in Python, you can use the memory_profiler module.
#pip install memory-profiler

# Save this as example.py
from memory_profiler import profile

@profile
def my_function():
    a = [i for i in range(10000)]
    b = sum(a)
    return b

if __name__ == "__main__":
    my_function()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-1fa333113da9> in <cell line: 0>()
#       5
#       6 # Save this as example.py
# ----> 7 from memory_profiler import profile
#       8
#       9 #@profile
#
# ModuleNotFoundError: No module named 'memory_profiler'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Q17: Write a Python program to create and write a list of numbers to a file, one number per line.

# List of numbers
numbers = [10, 20, 30, 40, 50]

# Write numbers to file
with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(f"{number}\n")

print("Numbers written to 'numbers.txt' successfully.")
# Out:
# Numbers written to 'numbers.txt' successfully.

# %%
#Q18: How would you implement a basic logging setup that logs to a file with rotation after 1MB?

import logging
from logging.handlers import RotatingFileHandler

# Configure rotating log handler
log_handler = RotatingFileHandler(
    filename='app.log',     # Log file name
    maxBytes=1_000_000,     # Rotate after 1MB
    backupCount=3           # Keep last 3 log files
)

# Set format and level
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
log_handler.setFormatter(formatter)

logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.addHandler(log_handler)

# Test logging
for i in range(10000):
    logger.info(f"Logging line number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:Logging line number 5000
# INFO:root:Logging line number 5001
# INFO:root:Logging line number 5002
# INFO:root:Logging line number 5003
# INFO:root:Logging line number 5004
# INFO:root:Logging line number 5005
# INFO:root:Logging line number 5006
# INFO:root:Logging line number 5007
# INFO:root:Logging line number 5008
# INFO:root:Logging line number 5009
# INFO:root:Logging line number 5010
# INFO:root:Logging line number 5011
# INFO:root:Logging line number 5012
# INFO:root:Logging line number 5013
# INFO:root:Logging line number 5014
# INFO:root:Logging line number 5015
# INFO:root:Logging line number 5016
# INFO:root:Logging line number 5017
# INFO:root:Logging line number 5018
# INFO:root:Logging line number 5019
# INFO:root:Logging line number 5020
# INFO:root:Logging line number 5021
# INFO:root:Logging line number 5022
# INFO:root:Logging line number 5023
# INFO:root:Logging line number 5024
# ...

# %%
#Q19: Write a program that handles both IndexError and KeyError using a try-except block.

my_list = [1, 2, 3]
my_dict = {"a": 10, "b": 20}

try:
    # Attempt to access an invalid index
    print("List value:", my_list[5])

    # Attempt to access a non-existent key
    print("Dict value:", my_dict["z"])

except IndexError:
    print("Error: List index is out of range.")

except KeyError:
    print("Error: Dictionary key not found.")
# Out:
# Error: List index is out of range.

# %%
#Q20: How would you open a file and read its contents using a context manager in Python?

with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, this is a sample text.This is new content being appended.

# %%
#Q21: Write a Python program that reads a file and prints the number of occurrences of a specific word.


def count_word_occurrences(filename, target_word):
    try:
        with open(filename, "r") as file:
            content = file.read().lower()
            word_count = content.count(target_word.lower())
            print(f"The word '{target_word}' occurs {word_count} times.")
    except FileNotFoundError:
        print("Error: File not found.")


# Example usage
count_word_occurrences("sample.txt", "python")
# Out:
# Error: File not found.

# %%
#Q22: How can you check if a file is empty before attempting to read its contents?

# Method 1: Using os.stat()
import os

file_path = "example.txt"

if os.path.exists(file_path) and os.stat(file_path).st_size == 0:
    print("The file is empty.")
else:
    with open(file_path, "r") as file:
        content = file.read()
        print(content)

# Method 2: Read and check content
with open("example.txt", "r") as file:
    content = file.read()
    if not content.strip():
        print("The file is empty.")
    else:
        print("File content:\n", content)
# Out:
# Hello, this is a sample text.This is new content being appended.
#
# File content:
#  Hello, this is a sample text.This is new content being appended.

# %%
#Q23: Write a Python program that writes to a log file when an error occurs during file handling.

import logging

# Configure logging
logging.basicConfig(filename='file_error.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

try:
    # Attempt to open a non-existent file
    with open("non_existing_file.txt", "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError as e:
    logging.error("File handling error: %s", e)
    print("An error occurred. Check 'file_error.log' for details.")
# Out:
# ERROR:root:File handling error: [Errno 2] No such file or directory: 'non_existing_file.txt'
# An error occurred. Check 'file_error.log' for details.
